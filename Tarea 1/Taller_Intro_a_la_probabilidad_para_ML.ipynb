# %% [markdown]
# <a href="https://colab.research.google.com/github/fedesierra613/Inteligencia_Artificial/blob/main/Taller_Intro_a_la_probabilidad_para_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea #1
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios
# 2. Ordene de menor a mayor y grafique
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=1000
m=300
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Media=", mean,"Var=", var,"Skew=", skew,"Kurt=", kurt)
# Out:
# Media= 0.3 Var= 0.21 Skew= 0.8728715609439694 Kurt= -1.2380952380952381

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.308 var_est= 0.21313599999999996

# %% [markdown]
# **Ahora realizaremos el mismo proceso pero para la distribucion de probabilidad binomial**

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n,p = 10, 0.5
from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
r = binom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial con p="+str(p)+" y con n="+str(n))
plt.show()
print("Media=", mean,"Var=", var,"Skew=", skew,"Kurt=", kurt)
# Out:
# Media= 5.0 Var= 2.5 Skew= 0.0 Kurt= -0.2

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomiales ordenados con p="+str(p)+"y la suma de n="+str(n))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p)+" y con n="+str(n))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"y n=",n,", son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 y n= 10 , son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 5.038 var_est= 2.2525560000000002

# %% [markdown]
# **Repitiendo para la distribución geométrica**

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3
from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geométrica con p="+str(p))
plt.show()
print("Media=", mean,"Var=", var,"Skew=", skew,"Kurt=", kurt)
# Out:
# Media= 3.3333333333333335 Var= 7.777777777777779 Skew= 2.031888635868469 Kurt= 6.128571428571429

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geométricos ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la geométrica con p=",p,", son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la geométrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la geométrica con p= 0.3 , son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la geométrica con p= 0.3 son u_est= 3.311 var_est= 6.870279

# %% [markdown]
# **Para poisson**

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')
r = poisson.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Poisson con p="+str(L))
plt.show()
print("Media=", mean,"Var=", var,"Skew=", skew,"Kurt=", kurt)
# Out:
# Media= 5.0 Var= 5.0 Skew= 0.4472135954999579 Kurt= 0.2

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos poisson ordenados con p="+str(L))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos poisson con p="+str(L))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la geométrica con L=",L,", son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la poisson con L=",L,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la geométrica con L= 5 , son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para la poisson con L= 5 son u_est= 5.034 var_est= 4.558843999999999

# %% [markdown]
# **Y finalmente para la binomial negativa**

# %%
#Binomial negativa con parametro p después de n fallos
n,p = 5,0.5
from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(n, p, moments='mvsk')
r = nbinom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial negativa con p="+str(p)+" y con n="+str(n))
plt.show()
print("Media=", mean,"Var=", var,"Skew=", skew,"Kurt=", kurt)
# Out:
# Media= 5.0 Var= 10.0 Skew= 0.9486832980505138 Kurt= 1.3

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomiales negativas ordenados con p="+str(p)+"y la suma de n="+str(n))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial negativa con p="+str(p)+" y con n="+str(n))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial negativa con p=",p,"y n=",n,", son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la binomial negativa con p= 0.5 y n= 5 , son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa con p= 0.5 son u_est= 4.904 var_est= 9.508784

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=1000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
from scipy.stats import norm
mean, var, skew, kurt = norm.stats(moments='mvsk',loc=u,scale=std)
r = norm.rvs (loc=u,scale=std, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con std="+str(std))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.971391002002103 var_est= 0.2653971302092896

# %% [markdown]
# **Para la T Student**

# %%
#T de Student con paramero K 
K=1.0
from scipy.stats import t
mean, var, skew, kurt = t.stats(df=K, moments='mvsk')
u=mean
std=var
r= t.rvs(df=K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t con media="+str(u)+" y var="+str(std))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t ordenados con media="+str(u)+" y var="+str(std))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos t con u="+str(u)+ " y var= "+str(std))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la T student son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la T student son u= inf var= nan
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 0.9310941833903253 var_est= 829.1720670823707

# %% [markdown]
# **Para la distribución exponencial**

# %%
# Exponencial con Lamnda L
L=0.3
from scipy.stats import exponnorm
mean, var, skew, kurt = exponnorm.stats(L, moments='mvsk')
r= exponnorm.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencial con L="+str(L))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencial ordenados con L="+str(L))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencial con L="+str(L))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la exponencial son u= 0.3 var= 1.09
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 0.2473584145662602 var_est= 1.0423841806086553

# %% [markdown]
# **Para la Chi cuadrarda**

# %%
#Chi cuadrada con K grados de libertad
K=3.0
from scipy.stats import chi2
mean, var, skew, kurt = chi2.stats(K, moments='mvsk')
r= chi2.rvs(K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos chi cuadrado con K="+str(K)+" grados de libertad")
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos chi cuadrado ordenados con K="+str(K)+" grados de libertad")
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos chi cuadrado ordenados con K="+str(K)+" grados de libertad")
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la chi cuadrada son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la chi cuadrada son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 2.90040019870204 var_est= 5.85275373803058

# %% [markdown]
# **Finalmente para la distribución Gamma**

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
from scipy.stats import gengamma
mean, var, skew, kurt = gengamma.stats(k,t, moments='mvsk')
r= gengamma.rvs(k,t, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos gamma con k="+str(k)+" y t="+str(t))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos gamma ordenados con k="+str(k)+" y t="+str(t))
# Out:
# Text(0.5, 1.0, '1000 puntos distribuidos gamma ordenados con k=2.54 y t=0.43')

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos gamma ordenados con k="+str(k)+" y t="+str(t))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la gamma son u= 14.35967866460761 var= 548.8900307790022
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 16.138033004995155 var_est= 671.4315464811605

# %% [markdown]
# # Conclusiones
#
# Como pudimos observar en la mayoria de casos la media y la varianza experimentales de las diferentes distribuciones tanto discretras como contínuas no distaban en mas de un 10% de estos valores en su forma teórica obtenida por medio de la funciones estadisticas brindadas por la biblioteca de scipy.
#
# Además graficando el histograma del experimento este concordaba con la grafica de la distribucion de probabilidad para cada caso, mostranado la relación que este tenia para cada valor de las variables que componen dicha función

# %% [markdown]
# # Referencias
#
#
# *   https://docs.scipy.org/doc/scipy/reference/stats.html
# *   https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
